# %%
import psycopg2

try:
    db5 = psycopg2.connect('''user='postgres'
                               password='2023'
                               dbname='jne'
                               host='localhost'
                               port=5432''')
    print ("Berhasil terkoneksi")
except:
    print ("Tidak dapat terkoneksi dengan database")
# Out:
# Berhasil terkoneksi

# %% [markdown]
# # Make Simple Data

# %%
cursor = db5.cursor()
 
# Doping EMPLOYEE table if already exists.
cursor.execute("DROP TABLE IF EXISTS publisher")
 
# Creating table as per requirement
sql = '''CREATE TABLE PUBLISHER(
                publisher_id SERIAL PRIMARY KEY,
                publisher_name VARCHAR(255) NOT NULL,
                publisher_estd INT,
                publsiher_location VARCHAR(255),
                publsiher_type VARCHAR(255)
)'''
cursor.execute(sql)
print("Table created successfully........")
db5.commit()
 
# Closing the connection
db5.close()
# Out:
# Table created successfully........

# %% [markdown]
# # Input Simple Data

# %%
import psycopg2


try:
	conn = psycopg2.connect(user="postgres",
								password="2023",
								host="localhost",
								port="5432",
								database="jne")
	cursor = conn.cursor()

	postgres_insert_query = """ INSERT INTO publisher(publisher_id,
	publisher_name, publisher_estd, publsiher_location, publsiher_type)
	VALUES (%s,%s,%s,%s,%s)"""
	record_to_insert = [(1, 'Packt', 1950,
						'chennai', 'books'),
						(2, 'Springer', 1950,
						'chennai', 'books'),
						(3, 'Springer', 1950,
						'chennai', 'articles'),
						(4, 'Oxford', 1950,
						'chennai', 'all'),
						(5, 'MIT', 1950,
						'chennai', 'books')]
	for i in record_to_insert:
		cursor.execute(postgres_insert_query, i)

		conn.commit()
		count = cursor.rowcount
	print(count, "Record inserted successfully \
	into publisher table")

except (Exception, psycopg2.Error) as error:
	print("Failed to insert record into publisher table", error)

finally:
	# closing database connection.
	if conn:
		cursor.close()
		conn.close()
		print("PostgreSQL connection is closed")
# Out:
# 1 Record inserted successfully 	into publisher table
# PostgreSQL connection is closed

# %% [markdown]
# # Input Data from sources

# %%
import pandas as pd

link_data = 'https://raw.githubusercontent.com/dsciencelabs/JNE_Data_Analytics_PySQL/main/data/data_latihan/users.csv'

df1 = pd.read_csv(link_data, sep=';' )
df1['created_at'] = pd.to_datetime(df1['created_at'])
df1
# Out:
#         id first_name  last_name                          email  age gender  \
# 0    44184   Patricia   Martinez   patriciamartinez@example.net   36      F
# 1    48555     Daniel   Mckinney     danielmckinney@example.com   67      M
# 2    80173     Regina     Hudson       reginahudson@example.org   61      F
# 3    85798    Kenneth     Montes      kennethmontes@example.org   16      M
# 4    88855    Zachary   Petersen    zacharypetersen@example.com   22      M
# ..     ...        ...        ...                            ...  ...    ...
# 495  23429  Cassandra   Mcdonald  cassandramcdonald@example.org   21      F
# 496  65664      Bobby  Rodriguez     bobbyrodriguez@example.org   20      M
# 497  65687       Todd    Patrick        toddpatrick@example.com   36      M
# 498  84918       John    Russell        johnrussell@example.com   70      M
# 499  87078       Kara       Bass           karabass@example.com   33      F
#
#     state                street_address postal_code        city  \
# 0    Acre  09526 Hudson Vista Suite 861   69917-400  Rio Branco
# 1    Acre             4676 Kurt Heights   69917-400  Rio Branco
# 2    Acre     20365 Boyd Spur Suite 939   69917-400  Rio Branco
# 3    Acre  0604 Dorothy Cliff Suite 086   69917-400  Rio Branco
# 4    Acre              8398 Flores Dale   69917-400  Rio Branco
# ..    ...                           ...         ...         ...
# 495  Ohio             599 Rebecca Brook       44134       Parma
# 496  Ohio  14326 Taylor Radial Apt. 120       44134       Parma
# 497  Ohio               989 Kelly Flats       44134       Parma
# 498  Ohio             19091 Baker Place       44134       Parma
# 499  Ohio             70219 Mary Bypass       44134       Parma
#
#            country      latitude     longitude traffic_source  \
# 0           Brasil  -9,945567619  -67,83560991         Search
# 1           Brasil  -9,945567619  -67,83560991         Search
# 2           Brasil  -9,945567619  -67,83560991        Display
# 3           Brasil  -9,945567619  -67,83560991         Search
# 4           Brasil  -9,945567619  -67,83560991         Search
# ..             ...           ...           ...            ...
# 495  United States   41,38478217  -81,70407797         Search
# 496  United States   41,38478217  -81,70407797       Facebook
# 497  United States   41,38478217  -81,70407797         Search
# 498  United States   41,38478217  -81,70407797         Search
# 499  United States   41,38478217  -81,70407797         Search
#
#              created_at
# 0   2023-06-27 06:07:04
# 1   2020-10-24 04:57:00
# 2   2022-01-03 07:23:00
# 3   2023-02-18 06:55:00
# 4   2022-01-27 17:30:00
# ..                  ...
# 495 2023-01-01 15:08:00
# 496 2019-06-01 09:31:00
# 497 2020-08-29 08:29:00
# 498 2023-02-28 10:53:00
# 499 2020-02-06 03:48:00
#
# [500 rows x 15 columns]

# %% [markdown]
# # Step by step input data into PostgreSQL from Pandas dataframe

# %%
import psycopg2

try:
    db5 = psycopg2.connect('''user='postgres'
                               password='2023'
                               dbname='jne'
                               host='localhost'
                               port=5432''')
    print ("Berhasil terkoneksi")
except:
    print ("Tidak dapat terkoneksi dengan database")
    
# import packages
import psycopg2
import psycopg2.extras as extras
import pandas as pd


def execute_values(db5, df, table):

	tuples = [tuple(x) for x in df.to_numpy()]

	cols = ','.join(list(df.columns))

	# SQL query to execute
	query = "INSERT INTO %s(%s) VALUES %%s" % (table, cols)
	cursor = db5.cursor()
	try:
		extras.execute_values(cursor, query, tuples)
		db5.commit()
	except (Exception, psycopg2.DatabaseError) as error:
		print("Error: %s" % error)
		db5.rollback()
		cursor.close()
		return 1
	print("execute_values() done")
	cursor.close()



sql = '''CREATE TABLE trial_data(
                id SERIAL PRIMARY KEY,
                first_name VARCHAR(255) NOT NULL,
                last_name VARCHAR(255) NOT NULL,
                email VARCHAR(255) NOT NULL,
                age INT,
                gender Varchar (10) check (gender in ('F','M')),
                state VARCHAR(255) NOT NULL,
                street_address VARCHAR(255) NOT NULL,
                postal_code VARCHAR(255) NOT NULL,
                city VARCHAR(255) NOT NULL,
                country VARCHAR(255) NOT NULL,
                latitude VARCHAR(255) NOT NULL,
                longitude VARCHAR(255) NOT NULL,
                traffic_source VARCHAR(255) NOT NULL,
                created_at VARCHAR(255) NOT NULL
)'''

# creating a cursor
cursor = db5.cursor()
cursor.execute(sql)
data = df1

data = data[["id", "first_name", "last_name", "email", "age", "gender", "state", "street_address",
            "postal_code", "city", "country", "latitude", "longitude", "traffic_source", "created_at"]]

# using the function defined
execute_values(db5, data, 'trial_data')
# Out:
# Berhasil terkoneksi
# execute_values() done

# %% [markdown]
# # Shortcut input data from pandas

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
engine = create_engine('postgresql://postgres:2023@localhost:5432/jne')

df1.to_sql("table_name", engine)
# Out:
# 500

# %% [markdown]
# # Update Table

# %%
cursor = db5.cursor()

cursor.execute("UPDATE table_name SET country = 'Indonesia' WHERE city = 'Ames';")
db5.commit()
db5.close()

# %% [markdown]
# # Delete Data or Table

# %%
cursor = db5.cursor()

cursor.execute("DELETE FROM table_name WHERE id='43148';")
db5.commit()
db5.close()

# %% [markdown]
# # Read DAta From PostgreSQL

# %% [markdown]
# sebenarnya setelah data di update dan delete baru kita melakukan tarik data dari PostgreSQL

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
engine = create_engine('postgresql://postgres:2023@localhost:5432/jne')

df = pd.read_sql_query('select * from "table_name"',con=engine)
df
# Out:
#      index     id first_name last_name                         email  age  \
# 0        0  44184   Patricia  Martinez  patriciamartinez@example.net   36
# 1        1  48555     Daniel  Mckinney    danielmckinney@example.com   67
# 2        2  80173     Regina    Hudson      reginahudson@example.org   61
# 3        3  85798    Kenneth    Montes     kennethmontes@example.org   16
# 4        4  88855    Zachary  Petersen   zacharypetersen@example.com   22
# ..     ...    ...        ...       ...                           ...  ...
# 494     47  15088     Denise       Kim         denisekim@example.org   15
# 495     48  48105       Mike    Miller        mikemiller@example.com   30
# 496     49  56270  Christine    Gordon   christinegordon@example.com   61
# 497     50  93926     Sierra    Bailey      sierrabailey@example.net   19
# 498     51  89921      Scott  Castillo     scottcastillo@example.org   18
#
#     gender state                street_address postal_code        city  \
# 0        F  Acre  09526 Hudson Vista Suite 861   69917-400  Rio Branco
# 1        M  Acre             4676 Kurt Heights   69917-400  Rio Branco
# 2        F  Acre     20365 Boyd Spur Suite 939   69917-400  Rio Branco
# 3        M  Acre  0604 Dorothy Cliff Suite 086   69917-400  Rio Branco
# 4        M  Acre              8398 Flores Dale   69917-400  Rio Branco
# ..     ...   ...                           ...         ...         ...
# 494      F  Iowa   5868 Lisa Station Suite 160       50010        Ames
# 495      M  Iowa            08941 Raymond Mill       50010        Ames
# 496      F  Iowa              4127 Bailey Hill       50010        Ames
# 497      F  Iowa              3828 Donald Walk       50010        Ames
# 498      M  Iowa            130 Harris Orchard       50014        Ames
#
#        country      latitude     longitude traffic_source          created_at
# 0       Brasil  -9,945567619  -67,83560991         Search 2023-06-27 06:07:04
# 1       Brasil  -9,945567619  -67,83560991         Search 2020-10-24 04:57:00
# 2       Brasil  -9,945567619  -67,83560991        Display 2022-01-03 07:23:00
# 3       Brasil  -9,945567619  -67,83560991         Search 2023-02-18 06:55:00
# 4       Brasil  -9,945567619  -67,83560991         Search 2022-01-27 17:30:00
# ..         ...           ...           ...            ...                 ...
# 494  Indonesia   42,03294842  -93,59109706          Email 2021-07-01 15:03:00
# 495  Indonesia   42,03294842  -93,59109706         Search 2020-05-18 10:18:00
# 496  Indonesia   42,03294842  -93,59109706         Search 2021-06-15 14:01:00
# 497  Indonesia   42,03294842  -93,59109706         Search 2020-01-01 16:05:00
# 498  Indonesia   42,05085639  -93,69778249         Search 2021-12-16 17:00:00
#
# [499 rows x 16 columns]
